# %%
import matplotlib.pyplot as plt
import uncertainty_utils as utils
import importlib
import pandas as pd
importlib.reload(utils)
# Out:
# <module 'uncertainty_utils' from 'c:\\Users\\soren\\Documents\\GitHub\\reflexion-human-eval\\uncertainty_utils.py'>

# %% [markdown]
# OOD Calibration Plots

# %%
combined_df = utils.gen_plot("root/human_eval/best_k/ood-3.5/reflexion_1_gpt-3.5-turbo_pass_at_k_5.jsonl")
print(utils.calculate_calibration_error(combined_df))
print(utils.calculate_brier_score(combined_df))
# Out:
# before adjustment
# after adjustment
# [0.0, 65, 40.0, 60.0, 66.66666666666666, 100.0, 81.81818181818183, 93.33333333333333]
# Expected Calibration Error: 17.54
# Brier Score: 370.70
# 17.531071079458176
# 0.1984058906060395

# %% [markdown]
# OOD GPT-4

# %%
combined_df = utils.gen_plot("root/reflexion_scratch/reflexion_1_gpt-4_pass_at_k_5.jsonl")
print(utils.calculate_calibration_error(combined_df))
print(utils.calculate_brier_score(combined_df))
# Out:
# before adjustment
# 18.49032579511168
# 0.1398510645028156
